# %%
class Node:
  def __init__(self, e, n, p):
    self.element = e
    self.next = n
    self.prev = p

# %%
from ast import Pass
class DoublyList:
  
  def __init__(self, a):
  # Creates a Non Dummy Headed Circular Doubly Linked List using the values from the given array a.
    # To Do
    self.head=None
    self.head=Node(a[0],None,None)
    tail=self.head
    # temp=self.head
    for i in range(1,len(a)):
        n=Node(a[i],self.head,tail)
        tail.next=n
        # tail.prev=n
        n.prev=tail
        # n.next=tail
        tail=n
    self.head.prev=tail
    tail.next=self.head
    
  # Counts the number of Nodes in the list and return the number
  def countNode(self):
    # To Do
    count=1
    tail=self.head.next
    while tail!=self.head:
        count+=1
        tail=tail.next
    return count
         
  # prints the elements in the list
  def forwardprint(self):
    # To Do
   temp=self.head
   tail=self.head.next
   print(temp.element,end=',')
   while tail!=self.head:
       if tail.next!=self.head:
        print(tail.element,end=',')
       else:
        print(tail.element,'.')
        print()
       tail=tail.next

  
  # prints the elements in the list backward
  def backwardprint(self):
    # To Do

   temp=self.head
   tail=self.head.prev
   while tail!=self.head:
       print(tail.element,end=',')
       tail=tail.prev
   print(temp.element,end='.')
   print()

  # returns the reference of the at the given index. For invalid index return None.
  def nodeAt(self, idx):
    # To Do
    count=0
    temp=self.head
    if idx<0 and idx>len(a1):
        return 'Invalid index'
    while temp!=None:
        if count==idx:
            return temp
        else:
            count+=1
        temp=temp.next

  # returns the index of the containing the given element. if the element does not exist in the List, return -1.
  def indexOf(self, elem):
    # To Do
    count=0
    temp=self.head
    while temp!=None:               
        if temp.element==elem:
            return count
        else:
            count+=1            
        temp=temp.next
    if temp==None:
        return -1

  # inserts containing the given element at the given index Check validity of index. 
  def insert(self, elem, idx):
    # To Do
    if idx<0 and idx>=len(a2):
        return 'Invalid Index'
    temp=self.head
    new_node=Node(elem,None,None)
    if idx==0:
        tail=self.head
        while tail.next!=self.head:
            tail=tail.next
        # print(tail.element)
        tail.next=new_node
        new_node.next=self.head
        self.head.prev=new_node
        new_node.prev=tail
        self.head=new_node   
    else:
        pred=self.nodeAt(idx-1)
        succ=self.nodeAt(idx)
        pred.next=new_node
        new_node.prev=pred
        new_node.next=succ
        succ.prev=new_node
    return new_node
    
  # removes at the given index. returns element of the removed node. Check validity of index. return None if index is invalid.
  def remove(self, idx):
    # To Do
    temp=self.head
    if idx==0:
        dummy=temp
        last=self.head.prev
        second=temp.next
        last.next=second
        second.prev=last
        self.head=second
        return str(dummy.element)
    else:
        temp=self.head
        i=0
        while i<idx:
            temp=temp.next
            i+=1
        pred=self.nodeAt(idx-1)
        succ=self.nodeAt(idx+1)
        pred.next=succ
        succ.prev=pred
        return str(temp.element)


    # if idx==0:
    #     dummy=0
    #     dummy+=temp.element
    #     temp=temp.next
    #     temp.prev=self.head.prev
    # while temp!=temp.next:
    #     temp=temp.next
    # print(temp)


print("///  Test 01  ///")
a1 = [10, 20, 30, 40]
h1 = DoublyList(a1) # Creates a linked list using the values from the array

h1.forwardprint() # This should print: 10,20,30,40. 
h1.backwardprint() # This should print: 40,30,20,10. 
print(h1.countNode()) # This should print: 4

print("///  Test 02  ///")
# returns the reference of the at the given index. For invalid idx return None.
myNode = h1.nodeAt(2)
print(myNode.element) # This should print: 30. In case of

print("///  Test 03  ///")
# returns the index of the containing the given element. if the element does not exist in the List, return -1.
index = h1.indexOf(40)
print(index) # This should print: 3. In case of element that 
#doesn't exists in the list this will print -1.

print("///  Test 04  ///")

a2 = [10, 20, 30, 40]
h2 = DoublyList(a2) # uses the  constructor
h2.forwardprint() # This should print: 10,20,30,40.  

# inserts containing the given element at the given index. Check validity of index.
h2.insert(85,0)
h2.forwardprint() # This should print: 85,10,20,30,40. 
h2.backwardprint() # This should print: 40,30,20,10,85.

print()
h2.insert(95,3)
h2.forwardprint() # This should print: 85,10,20,95,30,40.  
h2.backwardprint() # This should print: 40,30,95,20,10,85.  

print()
h2.insert(75,6)
h2.forwardprint() # This should print: 85,10,20,95,30,40,75. 
h2.backwardprint() # This should print: 75,40,30,95,20,10,85. 

print("///  Test 05  ///")
a3 = [10, 20, 30, 40, 50, 60, 70]
h3 = DoublyList(a3) # uses the constructor
h3.forwardprint() # This should print: 10,20,30,40,50,60,70.  

# removes at the given index. returns element of the removed node. Check validity of index. return None if index is invalid.
print("Removed element: "+ h3.remove(0)) # This should print: Removed element: 10
h3.forwardprint() # This should print: 20,30,40,50,60,70.  
h3.backwardprint() # This should print: 70,60,50,40,30,20.  
print("Removed element: "+ h3.remove(3)) # This should print: Removed element: 50
h3.forwardprint() # This should print: 20,30,40,60,70.  
h3.backwardprint() # This should print: 70,60,40,30,20.  
print("Removed element: "+ h3.remove(4)) # This should print: Removed element: 70
h3.forwardprint() # This should print: 20,30,40,60. 
h3.backwardprint() # This should print: 60,40,30,20.
# Out:
# ///  Test 01  ///
# 10,20,30,40 .
#
# 40,30,20,10.
# 4
# ///  Test 02  ///
# 30
# ///  Test 03  ///
# 3
# ///  Test 04  ///
# 10,20,30,40 .
#
# 85,10,20,30,40 .
#
# 40,30,20,10,85.
#
# 85,10,20,95,30,40 .
#
# 40,30,95,20,10,85.
#
# 85,10,20,95,30,40,75 .
#
# 75,40,30,95,20,10,85.
# ///  Test 05  ///
# 10,20,30,40,50,60,70 .
#
# Removed element: 10
# 20,30,40,50,60,70 .
#
# 70,60,50,40,30,20.
# Removed element: 50
# 20,30,40,60,70 .
#
# 70,60,40,30,20.
# Removed element: 70
# 20,30,40,60 .
#
# 60,40,30,20.

# %%
print("///  Test 01  ///")
a1 = [10, 20, 30, 40]
h1 = DoublyList(a1) # Creates a linked list using the values from the array

h1.forwardprint() # This should print: 10,20,30,40. 
h1.backwardprint() # This should print: 40,30,20,10. 
print(h1.countNode()) # This should print: 4

print("///  Test 02  ///")
# returns the reference of the at the given index. For invalid idx return None.
myNode = h1.nodeAt(2)
print(myNode.element) # This should print: 30. In case of invalid index This will print "index error"

print("///  Test 03  ///")
# returns the index of the containing the given element. if the element does not exist in the List, return -1.
index = h1.indexOf(40)
print(index) # This should print: 3. In case of element that 
#doesn't exists in the list this will print -1.

print("///  Test 04  ///")

a2 = [10, 20, 30, 40]
h2 = DoublyList(a2) # uses the  constructor
h2.forwardprint() # This should print: 10,20,30,40.  

# inserts containing the given element at the given index. Check validity of index.
h2.insert(85,0)
h2.forwardprint() # This should print: 85,10,20,30,40. 
h2.backwardprint() # This should print: 40,30,20,10,85.

print()
h2.insert(95,3)
h2.forwardprint() # This should print: 85,10,20,95,30,40.  
h2.backwardprint() # This should print: 40,30,95,20,10,80.  

print()
h2.insert(75,6)
h2.forwardprint() # This should print: 85,10,20,95,30,40,75. 
h2.backwardprint() # This should print: 75,40,30,95,20,10,85. 


print("///  Test 05  ///")
a3 = [10, 20, 30, 40, 50, 60, 70]
h3 = DoublyList(a3) # uses the constructor
h3.forwardprint() # This should print: 10,20,30,40,50,60,70.  

# removes at the given index. returns element of the removed node. Check validity of index. return None if index is invalid.
print("Removed element: "+ h3.remove(0)) # This should print: Removed element: 10
h3.forwardprint() # This should print: 20,30,40,50,60,70.  
h3.backwardprint() # This should print: 70,60,50,40,30,20.  
print("Removed element: "+ h3.remove(3)) # This should print: Removed element: 50
h3.forwardprint() # This should print: 20,30,40,60,70.  
h3.backwardprint() # This should print: 70,60,40,30,20.  
print("Removed element: "+ h3.remove(4)) # This should print: Removed element: 70
h3.forwardprint() # This should print: 20,30,40,60. 
h3.backwardprint() # This should print: 60,40,30,20.
# Out:
# ///  Test 01  ///
# 10,20,30,40 .
#
# 40,30,20,10.
# 4
# ///  Test 02  ///
# 30
# ///  Test 03  ///
# 3
# ///  Test 04  ///
# 10,20,30,40 .
#
# 10,20,30,40 .
#
# 40,30,20,10.
#
# 10,20,30,40 .
#
# 40,30,20,10.
#
# 10,20,30,40 .
#
# 40,30,20,10.
# ///  Test 05  ///
# 10,20,30,40,50,60,70 .
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-3ed0493810b2> in <module>
#      47
#      48 # removes at the given index. returns element of the removed node. Check validity of index. return None if index is invalid.
# ---> 49 print("Removed element: "+ h3.remove(0)) # This should print: Removed element: 10
#      50 h3.forwardprint() # This should print: 20,30,40,50,60,70.
#      51 h3.backwardprint() # This should print: 70,60,50,40,30,20.
#
# TypeError: can only concatenate str (not "NoneType") to str
